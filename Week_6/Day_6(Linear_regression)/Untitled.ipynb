# %% [markdown]
# # Linear Regression

# %% [markdown]
# In this lab we will use simple linear regression to predict the car price
# Objective:
# * To know if the dealer is offering fair value.
# * To Kknow if i put a fair value on my car

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
df = pd.read_csv('../../Data/automobileEDA.csv')
df
# Out:
#      symboling  normalized-losses         make aspiration num-of-doors  \
# 0            3                122  alfa-romero        std          two
# 1            3                122  alfa-romero        std          two
# 2            1                122  alfa-romero        std          two
# 3            2                164         audi        std         four
# 4            2                164         audi        std         four
# ..         ...                ...          ...        ...          ...
# 196         -1                 95        volvo        std         four
# 197         -1                 95        volvo      turbo         four
# 198         -1                 95        volvo        std         four
# 199         -1                 95        volvo      turbo         four
# 200         -1                 95        volvo      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# ...

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price',
#        'city-L/100km', 'horsepower-binned', 'diesel', 'gas'],
#       dtype='object')

# %%
x = df.drop('price', axis=1)
y = df['price']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# %%
x_train.shape, y_train.shape
# Out:
# ((160, 28), (160,))

# %%
x_simple_train = x_train['highway-mpg'].values.reshape(-1, 1)
x_simple_test = x_test['highway-mpg'].values.reshape(-1,1)

# %%
simple_lm = LinearRegression()
simple_lm.fit(x_simple_train, y_train)
# Out:
# LinearRegression()

# %%
predic = simple_lm.predict(x_simple_test)
predic
# Out:
# array([12166.10030237,  7173.74640389,  9928.14855478,  8550.94747933,
#        15436.95285656,  6140.8455973 , 20429.30675504, 10616.7490925 ,
#        15264.80272213,  7518.04667275, 11305.34963022,  8550.94747933,
#        15436.95285656, 16297.70352871, 14576.2021844 , 12166.10030237,
#         5452.24505958, 13715.45151225,  7345.89653832, 10100.29868921,
#        10272.44882364,  7518.04667275, 26798.86172898, 11821.80003351,
#         5796.54532844, 25765.96092239, 15436.95285656,  7173.74640389,
#        11305.34963022,  7345.89653832, 15092.6525877 , 10616.7490925 ,
#        12854.7008401 ,  7345.89653832, 23183.70890593, 23011.5587715 ,
#        15436.95285656,  9583.84828592, 21634.35769606, 16642.00379757,
#         7173.74640389])

# %%
simple_lm.coef_.item()
# Out:
# 172.15013443062284

# %%
x_simple_train = x_train['engine-size'].values.reshape(-1, 1)
x_simple_test = x_test['engine-size'].values.reshape(-1,1)
simple_lm = LinearRegression()
simple_lm.fit(x_simple_train, y_train)
predic = simple_lm.predict(x_simple_test)
simple_lm.coef_.item()
# Out:
# 166.58375411113173

# %%
x_simple_train = x_train['horsepower'].values.reshape(-1, 1)
x_simple_test = x_test['horsepower'].values.reshape(-1,1)
simple_lm = LinearRegression()
simple_lm.fit(x_simple_train, y_train)
predic = simple_lm.predict(x_simple_test)
simple_lm.coef_.item()
# Out:
# 172.15013443062284

# %%
to_select=df.loc[:, ['engine-size', 'horsepower', 'highway-mpg', 'curb-weight']]
to_select
# Out:
#      engine-size  horsepower  highway-mpg  curb-weight
# 0            130       111.0           27         2548
# 1            130       111.0           27         2548
# 2            152       154.0           26         2823
# 3            109       102.0           30         2337
# 4            136       115.0           22         2824
# ..           ...         ...          ...          ...
# 196          141       114.0           28         2952
# 197          141       160.0           25         3049
# 198          173       134.0           23         3012
# 199          145       106.0           27         3217
# 200          141       114.0           25         3062
#
# [201 rows x 4 columns]

# %%
to_select=['horsepower','engine-size','highway-mpg','curb-weight']
x_train_multi=x_train[to_select].values
y_train_mult=y_train[to_select].values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 3
#       1 to_select=['horsepower','engine-size','highway-mpg','curb-weight']
#       2 x_train_multi=x_train[to_select].values
# ----> 3 y_train_mult=y_train[to_select].values
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:1072, in Series.__getitem__(self, key)
#    1069     key = np.asarray(key, dtype=bool)
#    1070     return self._get_rows_with_mask(key)
# -> 1072 return self._get_with(key)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:1113, in Series._get_with(self, key)
#    1110         return self.iloc[key]
#    1112 # handle the dup indexing case GH#4246
# -> 1113 return self.loc[key]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
# ...
