# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
a = np.random.randint(20, size=(7))
b = np.random.randint(20, size=(7))
plt.plot(a,b)

# %%
df = pd.read_csv("../../Data/cricket_scores.csv")
df.head()
# Out:
#   Batting_team  Run  Over  Wickets
# 0    Newzeland    6   1.0        0
# 1    Newzeland   10   2.0        0
# 2    Newzeland   21   3.0        0
# 3    Newzeland   21   4.0        1
# 4    Newzeland   29   5.0        2

# %%
nz_scores=df.loc[df['Batting_team']=='Newzeland']
nz_scores.shape
# Out:
# (20, 4)

# %%
nz_over=nz_scores['Over']
nz_runs=nz_scores['Run']
plt.plot(nz_over,nz_runs, marker='o')
plt.xlabel('Runs')
plt.ylabel('Overs')
plt.show()

# %% [markdown]
# <h2>Time Series Data</h2>

# %%
df = pd.read_csv('../../Data/AirPassengers.csv')
df.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
plt.plot(df['Month'], df['#Passengers'], marker='o', markersize=5)
plt.title("Time Series Data")
plt.ylabel("Passengers")
plt.xlabel("Months")
plt.show()

# %% [markdown]
# <h2>Growth over Time</h2>

# %%
df= pd.DataFrame({"normal":[i for  i in range (1,10)],
     "square": [i*i for  i in range(1,10)],
     "cube": [i**3 for  i in range (1,10)],
     "log": [np.log(i) for  i in range (1,10)],
     "linear": [i+3 for i in range(1,10)]})
df
# Out:
#    normal  square  cube       log  linear
# 0       1       1     1  0.000000       4
# 1       2       4     8  0.693147       5
# 2       3       9    27  1.098612       6
# 3       4      16    64  1.386294       7
# 4       5      25   125  1.609438       8
# 5       6      36   216  1.791759       9
# 6       7      49   343  1.945910      10
# 7       8      64   512  2.079442      11
# 8       9      81   729  2.197225      12

# %%
plt.plot(df['normal'],df['square'], marker='o')

# %%
plt.plot(df['normal'],df['cube'], marker='o')

# %%
plt.plot(df['normal'],df['log'], marker='o')

# %%
plt.plot(df['normal'],df['linear'], marker='o')

# %%
df = pd.read_csv("../../Data/bike_rental_datasets.csv")
df
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# ...

# %%
df['dteday'] = pd.to_datetime(df['dteday'])
df.set_index(df['dteday'], inplace=True)
df
# Out:
#             instant     dteday  season  yr  mnth  hr  holiday  weekday  \
# dteday
# 2011-01-01        1 2011-01-01       1   0     1   0        0        6
# 2011-01-01        2 2011-01-01       1   0     1   1        0        6
# 2011-01-01        3 2011-01-01       1   0     1   2        0        6
# 2011-01-01        4 2011-01-01       1   0     1   3        0        6
# 2011-01-01        5 2011-01-01       1   0     1   4        0        6
# ...             ...        ...     ...  ..   ...  ..      ...      ...
# 2012-12-31    17375 2012-12-31       1   1    12  19        0        1
# 2012-12-31    17376 2012-12-31       1   1    12  20        0        1
# 2012-12-31    17377 2012-12-31       1   1    12  21        0        1
# 2012-12-31    17378 2012-12-31       1   1    12  22        0        1
# 2012-12-31    17379 2012-12-31       1   1    12  23        0        1
#
#             workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# dteday
# ...

# %%
df.reset_index(inplace = True)
df.shape
# Out:
# (17379, 18)

# %%
df=pd.read_csv('../../Data/HR_comma_sep.csv')
sts=df.groupby('time_spend_company').agg({'satisfaction_level':'mean', 'left':'sum'}).reset_index()
x=sts['time_spend_company']
y=sts['satisfaction_level']
z=sts['left']
weight=(z-z.min())/(z.max()-z.min())
weight
# Out:
# 0    0.033417
# 1    1.000000
# 2    0.561160
# 3    0.525221
# 4    0.131778
# 5    0.000000
# 6    0.000000
# 7    0.000000
# Name: left, dtype: float64

# %%
ax=plt.scatter(x,y, alpha=0.8, c=weight, cmap='coolwarm', s=weight*500+2)

# %%
 blank=[]
for i in range(1,6):
    y=(2*i)+3
    blank.append(y)

r=[]
for i in range(1,6):
    r.append(i)

plt.plot(r, blank,  marker='o')

# %%
for i in range(1,6):
    y=(3+i)+
# Out:
#   Cell In[23], line 2
#     y=(3+i)+
#             ^
# SyntaxError: invalid syntax
