# %%
import pandas as pd

# %%
df = pd.read_csv("Data/HR_comma_sep.csv")
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.head(10)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
# 5                0.41             0.50               2                   153
# 6                0.10             0.77               6                   247
# 7                0.92             0.85               5                   259
# 8                0.89             1.00               5                   224
# 9                0.42             0.53               2                   142
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# ...

# %%
df.tail(10)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14989                0.43             0.57               2
# 14990                0.89             0.88               5
# 14991                0.09             0.81               6
# 14992                0.40             0.48               2
# 14993                0.76             0.83               6
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 14989                   159                   3              1     1
# 14990                   228                   5              1     1
# 14991                   257                   4              0     1
# ...

# %%
df.shape
# Out:
# (14999, 10)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=14999, step=1)

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
import numpy as np
list  = np.random.randint(50, size=(2,6))
ndf=pd.DataFrame(list)
ndf
# Out:
#     0   1   2   3   4  5
# 0  19   5  36  11  20  8
# 1   2  46  39  14  26  5

# %%
df.dtypes
# Out:
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# left                       int64
# promotion_last_5years      int64
# Department                object
# salary                    object
# dtype: object

# %%
new_df = df
new_df.index[1] = 'le'
new_df.index
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 new_df = df
# ----> 2 new_df.index[1] = 'le'
#       3 new_df.index
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:5348, in Index.__setitem__(self, key, value)
#    5346 @final
#    5347 def __setitem__(self, key, value) -> None:
# -> 5348     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %%
new_df.rename(columns={"last_evaluation":"le"})
# Out:
#        satisfaction_level    le  number_project  average_montly_hours  \
# 0                    0.38  0.53               2                   157
# 1                    0.80  0.86               5                   262
# 2                    0.11  0.88               7                   272
# 3                    0.72  0.87               5                   223
# 4                    0.37  0.52               2                   159
# ...                   ...   ...             ...                   ...
# 14994                0.40  0.57               2                   151
# 14995                0.37  0.48               2                   160
# 14996                0.37  0.53               2                   143
# 14997                0.11  0.96               6                   280
# 14998                0.37  0.52               2                   158
#
#        time_spend_company  Work_accident  left  promotion_last_5years  \
# ...

# %%
df.to_numpy()
# Out:
# array([[0.38, 0.53, 2, ..., 0, 'sales', 'low'],
#        [0.8, 0.86, 5, ..., 0, 'sales', 'medium'],
#        [0.11, 0.88, 7, ..., 0, 'sales', 'medium'],
#        ...,
#        [0.37, 0.53, 2, ..., 0, 'support', 'low'],
#        [0.11, 0.96, 6, ..., 0, 'support', 'low'],
#        [0.37, 0.52, 2, ..., 0, 'support', 'low']], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
#Df occupies 1.1 MB
#Columns are of types: float64, int64, object
#total rows: 14999 
#no column contain null values

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
#We get the summary of each df column without the need of cxplict computation
#Only works in numerical data

# %%
df.describe(include='object')
# Out:
#        Department salary
# count       14999  14999
# unique         10      3
# top         sales    low
# freq         4140   7316

# %%
#for object type we get count, uique, top and freq

# %% [markdown]
# ***

# %% [markdown]
# <h1>Data Selection</h1>

# %%
#select columns using [], and dot(.) operator
#iloc
#loc
#unique() and nunique()
#value_counts()

# %%
print(df['satisfaction_level'])
# Out:
# 0        0.38
# 1        0.80
# 2        0.11
# 3        0.72
# 4        0.37
#          ...
# 14994    0.40
# 14995    0.37
# 14996    0.37
# 14997    0.11
# 14998    0.37
# Name: satisfaction_level, Length: 14999, dtype: float64

# %% [markdown]
# ***

# %%
print(df[['satisfaction_level', 'left']])
# Out:
#        satisfaction_level  left
# 0                    0.38     1
# 1                    0.80     1
# 2                    0.11     1
# 3                    0.72     1
# 4                    0.37     1
# ...                   ...   ...
# 14994                0.40     1
# 14995                0.37     1
# 14996                0.37     1
# 14997                0.11     1
# 14998                0.37     1
#
# [14999 rows x 2 columns]

# %% [markdown]
# iloc
# * ways to slice pandas df via integer value
# * it allows you to select data from a df using integer indices for both rows and columns
# * 1st row is 0 and 2nd row is 1 and so on
# * 1st column is 1, 2nd is 2 and so om

# %%
df.iloc[0,0]
# Out:
# 0.38

# %%
df.iloc[:3, -3:]
# Out:
#    promotion_last_5years Department  salary
# 0                      0      sales     low
# 1                      0      sales  medium
# 2                      0      sales  medium

# %% [markdown]
# loc
# * loc is used for label-based indexing
# * allows us to slice df using row label and column label instead of integer
# * syntax df.loc[row_label, column_label]

# %%
df.loc[0, 'satisfaction_level']
# Out:
# 0.38

# %%
df.loc[[0,1,2], ["satisfaction_level", "left", "salary"]]
# Out:
#    satisfaction_level  left  salary
# 0                0.38     1     low
# 1                0.80     1  medium
# 2                0.11     1  medium

# %% [markdown]
# unique and nunique

# %%
df['left'].unique()
# Out:
# array([1, 0])

# %%
df['left'].nunique()
# Out:
# 2

# %%
df['left'].value_counts()
# Out:
# left
# 0    11428
# 1     3571
# Name: count, dtype: int64

# %% [markdown]
# <h1>Aggregations</h1>

# %% [markdown]
# methods
# * mean()
# * std()
# * sum()
# * max()
# * min()

# %%
df['satisfaction_level'].mean()
# Out:
# 0.6128335222348156

# %%
df.describe(exclude='object').mean()
# Out:
# satisfaction_level       1875.356433
# last_evaluation          1875.424659
# number_project           1878.129456
# average_montly_hours     2032.124180
# time_spend_company       1878.244796
# Work_accident            1875.062041
# left                     1875.083001
# promotion_last_5years    1875.020694
# dtype: float64

# %%
print(df.columns)
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# left                       int64
# promotion_last_5years      int64
# Department                object
# salary                    object
# dtype: object

# %%
print(type(df.dtypes))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df['Work_accident'].sum()
# Out:
# 2169

# %% [markdown]
# ***

# %% [markdown]
# <h1>Missing Data</h1>

# %% [markdown]
# <h2>methods()</h2>
# <h3>
# <li>isnull() of isna()</li>
# <li>notnull() or notna()</li>
# <li>dropna()</li>
# <li>fillna</li></h3>

# %% [markdown]
# is null or isna
# * returns true if Df values are null
# * df method to get nan values from columns
# * it will ne considered null values if there are nan which is python default marler for null values
# * you can use df.isnull() method which is simply a alias of df.isna()

# %%
df.isnull()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                   False            False           False
# 1                   False            False           False
# 2                   False            False           False
# 3                   False            False           False
# 4                   False            False           False
# ...                   ...              ...             ...
# 14994               False            False           False
# 14995               False            False           False
# 14996               False            False           False
# 14997               False            False           False
# 14998               False            False           False
#
#        average_montly_hours  time_spend_company  Work_accident   left  \
# 0                     False               False          False  False
# 1                     False               False          False  False
# ...

# %%
df.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %%
df.notnull()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    True             True            True
# 1                    True             True            True
# 2                    True             True            True
# 3                    True             True            True
# 4                    True             True            True
# ...                   ...              ...             ...
# 14994                True             True            True
# 14995                True             True            True
# 14996                True             True            True
# 14997                True             True            True
# 14998                True             True            True
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                      True                True           True  True
# 1                      True                True           True  True
# ...

# %%
df.notna()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    True             True            True
# 1                    True             True            True
# 2                    True             True            True
# 3                    True             True            True
# 4                    True             True            True
# ...                   ...              ...             ...
# 14994                True             True            True
# 14995                True             True            True
# 14996                True             True            True
# 14997                True             True            True
# 14998                True             True            True
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                      True                True           True  True
# 1                      True                True           True  True
# ...

# %%
df.notnull().sum(axis=0)
# Out:
# satisfaction_level       14999
# last_evaluation          14999
# number_project           14999
# average_montly_hours     14999
# time_spend_company       14999
# Work_accident            14999
# left                     14999
# promotion_last_5years    14999
# Department               14999
# salary                   14999
# dtype: int64

# %%
df.dropna()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.fillna(5)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %% [markdown]
# ***

# %% [markdown]
# <h1>Data Manipulation</h1>

# %%
df['left'].replace({1: 'yes', 0: 'no'}, inplace=True)
df['left'].value_counts()
# Out:
# left
# no     11428
# yes     3571
# Name: count, dtype: int64

# %%
df_tsc = df.astype({'left': 'bool'})
df_tsc.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0  True                      0      sales
# 1                   6              0  True                      0      sales
# 2                   4              0  True                      0      sales
# 3                   5              0  True                      0      sales
# 4                   3              0  True                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
df_drop = df.drop('salary', axis=1)
df_drop.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident left  promotion_last_5years Department
# 0                   3              0  yes                      0      sales
# 1                   6              0  yes                      0      sales
# 2                   4              0  yes                      0      sales
# 3                   5              0  yes                      0      sales
# 4                   3              0  yes                      0      sales

# %%
df.sort_values(by='Work_accident', ascending=True)
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# 0                   0.38             0.53               2
# 9687                0.74             0.99               4
# 9689                0.69             0.91               6
# 9690                0.99             0.54               3
# 9691                0.66             0.75               4
# ...                  ...              ...             ...
# 9075                0.93             0.57               2
# 2335                0.97             0.77               3
# 9071                0.96             0.74               5
# 5089                0.84             0.95               4
# 6895                0.69             0.91               4
#
#       average_montly_hours  time_spend_company  Work_accident left  \
# 0                      157                   3              0  yes
# 9687                   156                   3              0   no
# ...

# %%
df_dep_left = df.groupby('Department').agg({'promotion_last_5years': 'sum'})
df_dep_left
# Out:
#              promotion_last_5years
# Department
# IT                               3
# RandD                           27
# accounting                      14
# hr                              15
# management                      69
# marketing                       43
# product_mng                      0
# sales                          100
# support                         20
# technical                       28

# %%
df_inner = df.merge(
